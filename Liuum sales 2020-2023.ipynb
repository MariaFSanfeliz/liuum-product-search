# %% [markdown]
# #Libraries

# %%
#Libraries to help with reading and manipulating data
import numpy as np
import pandas as pd

#Libraries to help with data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #Loading data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
jewelry=pd.read_csv('/content/drive/MyDrive/Data Science and Business Analytics/Liuu,/sales_2020-01-01_2023-12-31 (1).csv')

# %%
jewelry2=pd.read_csv('/content/drive/MyDrive/Data Science and Business Analytics/Liuu,/sales_2020-01-01_2023-12-31.csv')

# %%
data=jewelry.copy()

# %%
salesdata=jewelry2.copy()

# %% [markdown]
# #Data Overview

# %%
data.head()
# Out:
#   api_client_title pos_location_name product_vendor order_name  \
# 0    Point of Sale             Reliz            NaN      #2964
# 1    Point of Sale    Distribuidores          liuum      #5965
# 2    Point of Sale    Distribuidores          liuum      #4168
# 3    Point of Sale    Distribuidores          liuum      #6829
# 4    Point of Sale    Distribuidores              C      #2833
#
#                              product_title product_type  orders  gross_sales  \
# 0  Ventas Reliz Jueves después de apertura          NaN       1      17840.0
# 1           Stud Piercing Acero Quirúrgico       Aretes       1      26000.0
# 2                             Stud Oro 10k       Aretes       1      24000.0
# 3                       LENTES VERANO 2022    Accesorio       1      17940.0
# 4                           Anillo Inicial      Anillos       1      17850.0
#
#    returns  net_sales  total_sales  total_cost
# 0      0.0    17840.0      17840.0        0.00
# ...

# %%
data.tail()
# Out:
#       api_client_title pos_location_name product_vendor order_name  \
# 31896    Point of Sale    Distribuidores              O      #9604
# 31897     Online Store               NaN            NaN      #1003
# 31898    Point of Sale         Monterrey            NaN     #12865
# 31899    Point of Sale  Liuum (Plaza B2)            NaN      #6199
# 31900     Online Store               NaN            NaN      #1047
#
#       product_title product_type  orders  gross_sales  returns  net_sales  \
# 31896  Aretes Alysa       Aretes       1        390.0   -390.0        0.0
# 31897           NaN          NaN       0          0.0   -120.0     -120.0
# 31898           NaN          NaN       0          0.0   -250.0     -250.0
# 31899           NaN          NaN       0          0.0   -288.0     -288.0
# 31900           NaN          NaN       0          0.0  -1160.0    -1160.0
#
#        total_sales  total_cost
# 31896          0.0         0.0
# 31897       -100.0         0.0
# ...

# %%
data.shape
# Out:
# (31901, 12)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31901 entries, 0 to 31900
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   api_client_title   31901 non-null  object
#  1   pos_location_name  30086 non-null  object
#  2   product_vendor     30196 non-null  object
#  3   order_name         31901 non-null  object
#  4   product_title      31365 non-null  object
#  5   product_type       29240 non-null  object
#  6   orders             31901 non-null  int64
#  7   gross_sales        31901 non-null  float64
#  8   returns            31901 non-null  float64
#  9   net_sales          31901 non-null  float64
#  10  total_sales        31901 non-null  float64
#  11  total_cost         31901 non-null  float64
# dtypes: float64(5), int64(1), object(6)
# memory usage: 2.9+ MB

# %%
data.isnull().sum()
# Out:
# api_client_title        0
# pos_location_name    1815
# product_vendor       1705
# order_name              0
# product_title         536
# product_type         2661
# orders                  0
# gross_sales             0
# returns                 0
# net_sales               0
# total_sales             0
# total_cost              0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.describe(include='all').T
# Out:
#                      count unique                           top   freq  \
# api_client_title     31901      3                 Point of Sale  30086
# pos_location_name    30086      7              Liuum (Plaza B2)  11309
# product_vendor       30196     71                         liuum   5742
# order_name           31901  13074                         #4266    156
# product_title        31365   3044  Eslabón dorado con zirconias    364
# product_type         29240     14                        Aretes  13065
# orders             31901.0    NaN                           NaN    NaN
# gross_sales        31901.0    NaN                           NaN    NaN
# returns            31901.0    NaN                           NaN    NaN
# net_sales          31901.0    NaN                           NaN    NaN
# total_sales        31901.0    NaN                           NaN    NaN
# total_cost         31901.0    NaN                           NaN    NaN
#
# ...

# %%
salesdata.head()
# Out:
#    Identificación del pedido  Identificación de venta  \
# 0              2040938627181            6396537962605
# 1              2040938627181            6396537995373
# 2              2041004163181            6396735651949
# 3              2041004163181            6396735684717
# 4              2041052233837            6396876030061
#
#                        Fecha Pedido Tipo de transacción Tipo de venta  \
# 0  2020-01-15T20:10:19-07:00  #1003             product         order
# 1  2020-01-15T20:10:19-07:00  #1003            shipping         order
# 2  2020-01-15T21:11:40-07:00  #1004             product         order
# 3  2020-01-15T21:11:40-07:00  #1004            shipping         order
# 4  2020-01-15T22:03:23-07:00  #1005             product         order
#
#   Canal de ventas Sucursal de POS País de facturación Región de facturación  \
# 0    Online Store             NaN       United States              New York
# ...

# %%
salesdata.tail()
# Out:
#        Identificación del pedido  Identificación de venta  \
# 35579              5913675628653           17579886772333
# 35580              5913675628653           17579886739565
# 35581              5913703841901           17579968659565
# 35582              5913703841901           17579968626797
# 35583              5913703841901           17579968692333
#
#                            Fecha  Pedido Tipo de transacción Tipo de venta  \
# 35579  2023-12-30T17:35:40-06:00  #14110             product         order
# 35580  2023-12-30T17:35:40-06:00  #14110             product         order
# 35581  2023-12-30T18:11:07-06:00  #14111             product         order
# 35582  2023-12-30T18:11:07-06:00  #14111             product         order
# 35583  2023-12-30T18:11:07-06:00  #14111             product         order
#
#       Canal de ventas Sucursal de POS País de facturación  \
# 35579   Point of Sale           Reliz                 NaN
# ...

# %%
salesdata.shape
# Out:
# (35584, 27)

# %%
salesdata.describe(include='all').T
# Out:
#                              count unique                           top  \
# Identificación del pedido  35584.0    NaN                           NaN
# Identificación de venta    35584.0    NaN                           NaN
# Fecha                        35584  13442     2021-10-19T23:33:29-06:00
# Pedido                       35584  13059                         #7640
# Tipo de transacción          35584      4                       product
# Tipo de venta                35584      2                         order
# Canal de ventas              35584      3                 Point of Sale
# Sucursal de POS              33721      7              Liuum (Plaza B2)
# País de facturación           1625      3                        Mexico
# Región de facturación         1625     32                     Chihuahua
# Ciudad de facturación         1611    121                     Chihuahua
# País del envío                1417      2                        Mexico
# ...

# %%
salesdata.duplicated().sum()
# Out:
# 0

# %%
salesdata.isnull().sum()
# Out:
# Identificación del pedido        0
# Identificación de venta          0
# Fecha                            0
# Pedido                           0
# Tipo de transacción              0
# Tipo de venta                    0
# Canal de ventas                  0
# Sucursal de POS               1863
# País de facturación          33959
# Región de facturación        33959
# Ciudad de facturación        33973
# País del envío               34167
# Región del envío             34167
# Ciudad del envío             34181
# Tipo de producto              2424
# Proveedor del producto        1436
# Producto                       244
# Variante                     21524
# SKU de la variante           23627
# Cantidad neta                    0
# Ventas brutas                    0
# Descuentos                       0
# Devoluciones                     0
# Ventas netas                     0
# Envíos                           0
# Impuestos                        0
# Ventas totales                   0
# ...

# %%
salesdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35584 entries, 0 to 35583
# Data columns (total 27 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Identificación del pedido  35584 non-null  int64
#  1   Identificación de venta    35584 non-null  int64
#  2   Fecha                      35584 non-null  object
#  3   Pedido                     35584 non-null  object
#  4   Tipo de transacción        35584 non-null  object
#  5   Tipo de venta              35584 non-null  object
#  6   Canal de ventas            35584 non-null  object
#  7   Sucursal de POS            33721 non-null  object
#  8   País de facturación        1625 non-null   object
#  9   Región de facturación      1625 non-null   object
#  10  Ciudad de facturación      1611 non-null   object
#  11  País del envío             1417 non-null   object
#  12  Región del envío           1417 non-null   object
# ...

# %% [markdown]
# #EDA

# %% [markdown]
# ##Functions

# %%
D

# %% [markdown]
# ##Univariate

# %% [markdown]
# ##Bivariate
